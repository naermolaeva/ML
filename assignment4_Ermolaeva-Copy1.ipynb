# %% [markdown]
# # Assignment 4: Named entity recognition
#
# Построить модель для обнаружения и классификации именованных сущностей (named entities). На базе корпуса CoNLL 2002.
#
# Используйте в своем решении ансамбли над решающими деревьями: RandomForest, Gradient Boosting (xgboost, lightgbm, catboost)
# Tutorials:
# 1. https://github.com/Microsoft/LightGBM/tree/master/examples/python-guide
# 1. https://github.com/catboost/tutorials
#
#
# Чем больше baseline'ов вы превзойдете, тем выше ваша оценка
# Метрика качества f1 (f1_macro) (чем выше, тем лучше)
#
# baseline 1: 0.0604      random labels
# baseline 2: 0.3966      PoS features + logistic regression
# baseline 3: 0.8122      word2vec cbow embedding + baseline 2 + svm
#
# ! Your results must be reproducible. Если ваша модель - стохастическая, то вы явно должны задавать все seed и random_state в параметрах моделей
#
# bonus, think about:
# 1. How can you exploit that words belong to some sentence?
# 2. Why we selected f1 score with macro averaging as our classification quality measure? What other metrics are suitable?

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn import model_selection
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


SEED=1337

# %%
df = pd.read_csv('ner_short.csv', index_col=0)
df.head()
# Out:
#   next-next-pos next-next-word next-pos      next-word  pos    prev-pos  \
# 0           NNS  demonstrators       IN             of  NNS  __START1__
# 1           VBP           have      NNS  demonstrators   IN         NNS
# 2           VBN        marched      VBP           have  NNS          IN
# 3            IN        through      VBN        marched  VBP         NNS
# 4           NNP         London       IN        through  VBN         VBP
#
#   prev-prev-pos prev-prev-word      prev-word  sentence_idx           word tag
# 0    __START2__     __START2__     __START1__           1.0      Thousands   O
# 1    __START1__     __START1__      Thousands           1.0             of   O
# 2           NNS      Thousands             of           1.0  demonstrators   O
# 3            IN             of  demonstrators           1.0           have   O
# 4           NNS  demonstrators           have           1.0        marched   O

# %%
# number of sentences
df.sentence_idx.max()
# Out:
# 1500.0

# %%
# class distribution
df.tag.value_counts(normalize=True )
# Out:
# O        0.852828
# B-geo    0.027604
# B-gpe    0.020935
# B-org    0.020247
# I-per    0.017795
# B-tim    0.016927
# B-per    0.015312
# I-org    0.013937
# I-geo    0.005383
# I-tim    0.004247
# B-art    0.001376
# I-gpe    0.000837
# I-art    0.000748
# B-eve    0.000628
# I-eve    0.000508
# B-nat    0.000449
# I-nat    0.000239
# Name: tag, dtype: float64

# %%
# sentence length
tdf = df.set_index('sentence_idx')
tdf['length'] = df.groupby('sentence_idx').tag.count()
df = tdf.reset_index(drop=False)

# %%
# encode categorial variables

le = LabelEncoder()
df['pos'] = le.fit_transform(df.pos)
df['next-pos'] = le.fit_transform(df['next-pos'])
df['next-next-pos'] = le.fit_transform(df['next-next-pos'])
df['prev-pos'] = le.fit_transform(df['prev-pos'])
df['prev-prev-pos'] = le.fit_transform(df['prev-prev-pos'])

# %%
df.head()
# Out:
#    sentence_idx  next-next-pos next-next-word  next-pos      next-word  pos  \
# 0           1.0             18  demonstrators         9             of   18
# 1           1.0             33           have        18  demonstrators    9
# 2           1.0             32        marched        33           have   18
# 3           1.0              9        through        32        marched   33
# 4           1.0             16         London         9        through   32
#
#    prev-pos  prev-prev-pos prev-prev-word      prev-word           word tag  \
# 0        39             40     __START2__     __START1__      Thousands   O
# 1        18             39     __START1__      Thousands             of   O
# 2         9             18      Thousands             of  demonstrators   O
# 3        18              9             of  demonstrators           have   O
# 4        33             18  demonstrators           have        marched   O
#
#    length
# 0      48
# 1      48
# 2      48
# 3      48
# 4      48

# %%
# splitting
y = LabelEncoder().fit_transform(df.tag)

df_train, df_test, y_train, y_test = model_selection.train_test_split(df, y, stratify=y, 
                                                                      test_size=0.25, random_state=SEED, shuffle=True)
print('train', df_train.shape[0])
print('test', df_test.shape[0])
# Out:
# train 50155
# test 16719

# %%
# some wrappers to work with word2vec
from gensim.models.word2vec import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.base import TransformerMixin
from collections import defaultdict

   
class Word2VecWrapper(TransformerMixin):
    def __init__(self, window=5,negative=5, size=100, iter=100, is_cbow=False, random_state=SEED):
        self.window_ = window
        self.negative_ = negative
        self.size_ = size
        self.iter_ = iter
        self.is_cbow_ = is_cbow
        self.w2v = None
        self.random_state = random_state
        
    def get_size(self):
        return self.size_

    def fit(self, X, y=None):
        """
        X: list of strings
        """
        sentences_list = [x.split() for x in X]
        self.w2v = Word2Vec(sentences_list, 
                            window=self.window_,
                            negative=self.negative_, 
                            size=self.size_, 
                            iter=self.iter_,
                            sg=not self.is_cbow_, seed=self.random_state)

        return self
    
    def has(self, word):
        return word in self.w2v

    def transform(self, X):
        """
        X: a list of words
        """
        if self.w2v is None:
            raise Exception('model not fitted')
        return np.array([self.w2v[w] if w in self.w2v else np.zeros(self.size_) for w in X ])

# %%
# %%time
# here we exploit that word2vec is an unsupervised learning algorithm
# so we can train it on the whole dataset (subject to discussion)

sentences_list = [x.strip() for x in ' '.join(df.word).split('.')]

w2v_cbow = Word2VecWrapper(window=5, negative=5, size=300, iter=300, is_cbow=True, random_state=SEED)
w2v_cbow.fit(sentences_list)
# Out:
# CPU times: user 29.5 s, sys: 351 ms, total: 29.8 s
# Wall time: 12.5 s

# %%
# %%time
# baseline 1 
# random labels
from sklearn.preprocessing import OneHotEncoder
from sklearn.dummy import DummyClassifier


columns = ['pos','next-pos','next-next-pos','prev-pos','prev-prev-pos']

model = Pipeline([
    ('enc', OneHotEncoder()),
    ('est', DummyClassifier(random_state=SEED)),
])

model.fit(df_train[columns], y_train)

print('train', metrics.f1_score(y_train, model.predict(df_train[columns]), average='macro'))
print('test', metrics.f1_score(y_test, model.predict(df_test[columns]), average='macro'))
# Out:
# train 0.05887736725599869
# test 0.060439542712750365
# CPU times: user 98.7 ms, sys: 17.1 ms, total: 116 ms
# Wall time: 122 ms

# %%
# %%time
# baseline 2 
# pos features + one hot encoding + logistic regression
from sklearn.preprocessing import OneHotEncoder


columns = ['pos','next-pos','next-next-pos','prev-pos','prev-prev-pos']

model = Pipeline([
    ('enc', OneHotEncoder()),
    ('est', LogisticRegressionCV(Cs=5, cv=5, n_jobs=-1, scoring='f1_macro', 
                             penalty='l2', solver='newton-cg', multi_class='multinomial', random_state=SEED)),
])

model.fit(df_train[columns], y_train)

print('train', metrics.f1_score(y_train, model.predict(df_train[columns]), average='macro'))
print('test', metrics.f1_score(y_test, model.predict(df_test[columns]), average='macro'))
# Out:
# train 0.46639500282346874
# test 0.39660981421559566
# CPU times: user 2min 40s, sys: 9.99 s, total: 2min 50s
# Wall time: 11min 32s

# %%
# %%time
## baseline 3
# use word2vec cbow embedding + baseline 2 + svm
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.svm import LinearSVC
import scipy.sparse as sp

embeding = w2v_cbow
encoder_pos = OneHotEncoder()
X_train = sp.hstack([
    embeding.transform(df_train.word),
    embeding.transform(df_train['next-word']),
    embeding.transform(df_train['next-next-word']),
    embeding.transform(df_train['prev-word']),
    embeding.transform(df_train['prev-prev-word']),
    encoder_pos.fit_transform(df_train[['pos','next-pos','next-next-pos','prev-pos','prev-prev-pos']])
])
X_test = sp.hstack([
    embeding.transform(df_test.word),
    embeding.transform(df_test['next-word']),
    embeding.transform(df_test['next-next-word']),
    embeding.transform(df_test['prev-word']),
    embeding.transform(df_test['prev-prev-word']),
    encoder_pos.transform(df_test[['pos','next-pos','next-next-pos','prev-pos','prev-prev-pos']])
])

model = model_selection.GridSearchCV(LinearSVC(penalty='l2', multi_class='ovr', random_state=SEED), 
                                    {'C': np.logspace(-4, 0, 5)}, 
                                    cv=3, scoring='f1_macro', n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print('train', metrics.f1_score(y_train, model.predict(X_train), average='macro'))
print('test', metrics.f1_score(y_test, model.predict(X_test), average='macro'))
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  6.1min finished
# train 0.9550564339022908
# test 0.8020799802744993
# CPU times: user 1min 59s, sys: 6.46 s, total: 2min 5s
# Wall time: 8min 13s

# %%
df_train.head()
# Out:
#        sentence_idx  next-next-pos next-next-word  next-pos next-word  pos  \
# 36858         153.0             35           that        18     camps   30
# 39120         259.0              7            the        28        to   32
# 53612         910.0             15       dictator        10    former    7
# 6150          280.0              9             of        15      risk    7
# 3771          169.0             10        Mexican         1         ,   16
#
#        prev-pos  prev-prev-pos prev-prev-word prev-word    word    tag  length
# 36858        16             16           June       Soh   found      O      54
# 39120        30              5            and       was   known      O      58
# 53612        30              1              ,    showed     the      O      50
# 6150          9              1              ,   despite     the      O      44
# 3771         15             16       Saltillo     plant  Friday  B-tim      52

# %% [markdown]
# **Будем также учитывать `sentence_idx` и `length`**

# %%
idxs = [0, 1, 3, 5, 6, 7, 12]
cols = list(df_train)
train_cols = list(np.array(cols)[idxs])

# %%
train_cols
# Out:
# ['sentence_idx',
#  'next-next-pos',
#  'next-pos',
#  'pos',
#  'prev-pos',
#  'prev-prev-pos',
#  'length']

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import KFold

# %%
params = {
    'iterations' : [500, 1000],
    'learning_rate' : [0.03, 1],
    'depth' : [8, 10]
}

# %%
model = CatBoostClassifier(
    loss_function='MultiClass',
    custom_loss=['F1'],
    random_seed=SEED,
    logging_level='Verbose'
)

# %%
# %%time
kf = KFold(n_splits=5, shuffle=True)
clf = model_selection.GridSearchCV(model, params, scoring='f1_macro', n_jobs=-1, cv=kf)
clf.fit(df_train[train_cols], y_train)
# Out:
# 0:	learn: -0.6013347	total: 211ms	remaining: 3m 31s
# 1:	learn: -5.6726363	total: 359ms	remaining: 2m 59s
# 2:	learn: -6.9616574	total: 499ms	remaining: 2m 45s
# 3:	learn: -6.6089993	total: 665ms	remaining: 2m 45s
# 4:	learn: -5.5586517	total: 825ms	remaining: 2m 44s
# 5:	learn: -5.3501627	total: 967ms	remaining: 2m 40s
# 6:	learn: -4.9516412	total: 1.11s	remaining: 2m 38s
# 7:	learn: -4.8114729	total: 1.26s	remaining: 2m 36s
# 8:	learn: -4.3101047	total: 1.41s	remaining: 2m 35s
# 9:	learn: -4.3394741	total: 1.55s	remaining: 2m 33s
# 10:	learn: -4.1811566	total: 1.68s	remaining: 2m 31s
# 11:	learn: -3.8724359	total: 1.82s	remaining: 2m 29s
# 12:	learn: -3.6842454	total: 1.96s	remaining: 2m 28s
# 13:	learn: -3.5410602	total: 2.09s	remaining: 2m 27s
# 14:	learn: -3.3792883	total: 2.23s	remaining: 2m 26s
# 15:	learn: -3.4562716	total: 2.36s	remaining: 2m 25s
# 16:	learn: -3.1474633	total: 2.5s	remaining: 2m 24s
# 17:	learn: -2.9723337	total: 2.64s	remaining: 2m 24s
# 18:	learn: -2.8639973	total: 2.78s	remaining: 2m 23s
# 19:	learn: -2.7774472	total: 2.92s	remaining: 2m 23s
# 20:	learn: -2.5756446	total: 3.06s	remaining: 2m 22s
# 21:	learn: -2.5046240	total: 3.2s	remaining: 2m 22s
# 22:	learn: -2.5165152	total: 3.33s	remaining: 2m 21s
# 23:	learn: -2.3380364	total: 3.47s	remaining: 2m 21s
# 24:	learn: -2.3045780	total: 3.6s	remaining: 2m 20s
# 25:	learn: -2.2152959	total: 3.75s	remaining: 2m 20s
# 26:	learn: -2.1492780	total: 3.88s	remaining: 2m 19s
# 27:	learn: -2.1069048	total: 4.02s	remaining: 2m 19s
# 28:	learn: -2.0041693	total: 4.16s	remaining: 2m 19s
# 29:	learn: -1.9810272	total: 4.3s	remaining: 2m 18s
# 30:	learn: -1.9540732	total: 4.43s	remaining: 2m 18s
# 31:	learn: -1.8421856	total: 4.57s	remaining: 2m 18s
# 32:	learn: -1.8224925	total: 4.71s	remaining: 2m 17s
# 33:	learn: -1.7864886	total: 4.84s	remaining: 2m 17s
# 34:	learn: -1.7579704	total: 4.98s	remaining: 2m 17s
# 35:	learn: -1.7300892	total: 5.12s	remaining: 2m 17s
# 36:	learn: -1.7212760	total: 5.26s	remaining: 2m 16s
# 37:	learn: -1.7098565	total: 5.4s	remaining: 2m 16s
# 38:	learn: -1.6935295	total: 5.54s	remaining: 2m 16s
# 39:	learn: -1.6793506	total: 5.68s	remaining: 2m 16s
# 40:	learn: -1.6688369	total: 5.83s	remaining: 2m 16s
# 41:	learn: -1.6441543	total: 5.96s	remaining: 2m 16s
# 42:	learn: -1.6127591	total: 6.11s	remaining: 2m 16s
# 43:	learn: -1.6007136	total: 6.26s	remaining: 2m 15s
# 44:	learn: -1.5873133	total: 6.4s	remaining: 2m 15s
# 45:	learn: -1.5768786	total: 6.54s	remaining: 2m 15s
# 46:	learn: -1.5471787	total: 6.69s	remaining: 2m 15s
# 47:	learn: -1.5330518	total: 6.83s	remaining: 2m 15s
# 48:	learn: -1.5140215	total: 6.96s	remaining: 2m 15s
# 49:	learn: -1.5073768	total: 7.09s	remaining: 2m 14s
# 50:	learn: -1.4975532	total: 7.23s	remaining: 2m 14s
# 51:	learn: -1.4839799	total: 7.36s	remaining: 2m 14s
# 52:	learn: -1.4728175	total: 7.5s	remaining: 2m 13s
# 53:	learn: -1.4662663	total: 7.63s	remaining: 2m 13s
# 54:	learn: -1.4568814	total: 7.77s	remaining: 2m 13s
# 55:	learn: -1.4316863	total: 7.91s	remaining: 2m 13s
# 56:	learn: -1.4209548	total: 8.05s	remaining: 2m 13s
# 57:	learn: -1.4119746	total: 8.29s	remaining: 2m 14s
# 58:	learn: -1.3797870	total: 8.46s	remaining: 2m 14s
# 59:	learn: -1.3708280	total: 8.62s	remaining: 2m 15s
# 60:	learn: -1.3673497	total: 8.77s	remaining: 2m 15s
# 61:	learn: -1.3581702	total: 8.91s	remaining: 2m 14s
# 62:	learn: -1.3508689	total: 9.04s	remaining: 2m 14s
# 63:	learn: -1.3462735	total: 9.18s	remaining: 2m 14s
# 64:	learn: -1.3394882	total: 9.31s	remaining: 2m 13s
# 65:	learn: -1.3355690	total: 9.45s	remaining: 2m 13s
# 66:	learn: -1.3302488	total: 9.58s	remaining: 2m 13s
# 67:	learn: -1.3259787	total: 9.72s	remaining: 2m 13s
# 68:	learn: -1.3195656	total: 9.86s	remaining: 2m 13s
# 69:	learn: -1.3156598	total: 9.99s	remaining: 2m 12s
# 70:	learn: -1.3117099	total: 10.1s	remaining: 2m 12s
# 71:	learn: -1.3063118	total: 10.3s	remaining: 2m 12s
# 72:	learn: -1.2927396	total: 10.4s	remaining: 2m 12s
# 73:	learn: -1.2802197	total: 10.5s	remaining: 2m 11s
# 74:	learn: -1.2738061	total: 10.7s	remaining: 2m 11s
# 75:	learn: -1.2657986	total: 10.8s	remaining: 2m 11s
# 76:	learn: -1.2570198	total: 11s	remaining: 2m 11s
# 77:	learn: -1.2525973	total: 11.1s	remaining: 2m 11s
# 78:	learn: -1.2474910	total: 11.2s	remaining: 2m 11s
# 79:	learn: -1.2320361	total: 11.4s	remaining: 2m 10s
# 80:	learn: -1.2197094	total: 11.5s	remaining: 2m 10s
# 81:	learn: -1.2099485	total: 11.6s	remaining: 2m 10s
# 82:	learn: -1.2070614	total: 11.8s	remaining: 2m 10s
# 83:	learn: -1.2031207	total: 11.9s	remaining: 2m 10s
# 84:	learn: -1.1901967	total: 12.1s	remaining: 2m 9s
# 85:	learn: -1.1708194	total: 12.2s	remaining: 2m 9s
# 86:	learn: -1.1584194	total: 12.3s	remaining: 2m 9s
# 87:	learn: -1.1560942	total: 12.5s	remaining: 2m 9s
# 88:	learn: -1.1523326	total: 12.6s	remaining: 2m 9s
# 89:	learn: -1.1481082	total: 12.7s	remaining: 2m 8s
# 90:	learn: -1.1453843	total: 12.9s	remaining: 2m 8s
# 91:	learn: -1.1304067	total: 13s	remaining: 2m 8s
# 92:	learn: -1.1224325	total: 13.2s	remaining: 2m 8s
# 93:	learn: -1.1158189	total: 13.3s	remaining: 2m 8s
# 94:	learn: -1.1027814	total: 13.4s	remaining: 2m 7s
# 95:	learn: -1.0951178	total: 13.6s	remaining: 2m 7s
# 96:	learn: -1.0906425	total: 13.7s	remaining: 2m 7s
# 97:	learn: -1.0830806	total: 13.8s	remaining: 2m 7s
# 98:	learn: -1.0806637	total: 14s	remaining: 2m 7s
# 99:	learn: -1.0772354	total: 14.1s	remaining: 2m 6s
# 100:	learn: -1.0749882	total: 14.2s	remaining: 2m 6s
# 101:	learn: -1.0708222	total: 14.4s	remaining: 2m 6s
# 102:	learn: -1.0677847	total: 14.5s	remaining: 2m 6s
# 103:	learn: -1.0653137	total: 14.6s	remaining: 2m 6s
# 104:	learn: -1.0625437	total: 14.8s	remaining: 2m 5s
# 105:	learn: -1.0580930	total: 14.9s	remaining: 2m 5s
# 106:	learn: -1.0563405	total: 15s	remaining: 2m 5s
# 107:	learn: -1.0509865	total: 15.2s	remaining: 2m 5s
# 108:	learn: -1.0467846	total: 15.3s	remaining: 2m 5s
# 109:	learn: -1.0444279	total: 15.5s	remaining: 2m 5s
# 110:	learn: -1.0420422	total: 15.6s	remaining: 2m 4s
# 111:	learn: -1.0378353	total: 15.7s	remaining: 2m 4s
# 112:	learn: -1.0359453	total: 15.9s	remaining: 2m 4s
# 113:	learn: -1.0339856	total: 16s	remaining: 2m 4s
# 114:	learn: -1.0322926	total: 16.1s	remaining: 2m 4s
# 115:	learn: -1.0300084	total: 16.3s	remaining: 2m 4s
# 116:	learn: -1.0249855	total: 16.4s	remaining: 2m 3s
# 117:	learn: -1.0224679	total: 16.6s	remaining: 2m 3s
# 118:	learn: -1.0155973	total: 16.7s	remaining: 2m 3s
# 119:	learn: -1.0134417	total: 16.8s	remaining: 2m 3s
# 120:	learn: -1.0116150	total: 17s	remaining: 2m 3s
# 121:	learn: -1.0090884	total: 17.1s	remaining: 2m 3s
# 122:	learn: -1.0000548	total: 17.3s	remaining: 2m 3s
# 123:	learn: -0.9916804	total: 17.4s	remaining: 2m 2s
# 124:	learn: -0.9884810	total: 17.5s	remaining: 2m 2s
# 125:	learn: -0.9873643	total: 17.7s	remaining: 2m 2s
# 126:	learn: -0.9844864	total: 17.8s	remaining: 2m 2s
# 127:	learn: -0.9811514	total: 17.9s	remaining: 2m 2s
# 128:	learn: -0.9759855	total: 18.1s	remaining: 2m 2s
# 129:	learn: -0.9742300	total: 18.2s	remaining: 2m 1s
# 130:	learn: -0.9721504	total: 18.4s	remaining: 2m 1s
# 131:	learn: -0.9664283	total: 18.5s	remaining: 2m 1s
# 132:	learn: -0.9651370	total: 18.6s	remaining: 2m 1s
# 133:	learn: -0.9631263	total: 18.8s	remaining: 2m 1s
# 134:	learn: -0.9608038	total: 18.9s	remaining: 2m 1s
# 135:	learn: -0.9592215	total: 19.1s	remaining: 2m 1s
# 136:	learn: -0.9533682	total: 19.2s	remaining: 2m
# 137:	learn: -0.9471493	total: 19.3s	remaining: 2m
# 138:	learn: -0.9429089	total: 19.5s	remaining: 2m
# 139:	learn: -0.9407239	total: 19.6s	remaining: 2m
# 140:	learn: -0.9388931	total: 19.7s	remaining: 2m
# 141:	learn: -0.9353689	total: 19.9s	remaining: 2m
# 142:	learn: -0.9341609	total: 20s	remaining: 2m
# 143:	learn: -0.9307852	total: 20.2s	remaining: 1m 59s
# 144:	learn: -0.9274174	total: 20.3s	remaining: 1m 59s
# 145:	learn: -0.9258629	total: 20.5s	remaining: 1m 59s
# 146:	learn: -0.9249970	total: 20.6s	remaining: 1m 59s
# 147:	learn: -0.9216566	total: 20.7s	remaining: 1m 59s
# 148:	learn: -0.9201905	total: 20.9s	remaining: 1m 59s
# 149:	learn: -0.9191392	total: 21s	remaining: 1m 59s
# 150:	learn: -0.9182453	total: 21.2s	remaining: 1m 58s
# 151:	learn: -0.9152056	total: 21.3s	remaining: 1m 58s
# 152:	learn: -0.9118759	total: 21.4s	remaining: 1m 58s
# 153:	learn: -0.9104198	total: 21.6s	remaining: 1m 58s
# 154:	learn: -0.9069465	total: 21.7s	remaining: 1m 58s
# 155:	learn: -0.9052288	total: 21.8s	remaining: 1m 58s
# 156:	learn: -0.9035088	total: 22s	remaining: 1m 57s
# 157:	learn: -0.8987479	total: 22.1s	remaining: 1m 57s
# 158:	learn: -0.8966638	total: 22.2s	remaining: 1m 57s
# 159:	learn: -0.8943604	total: 22.4s	remaining: 1m 57s
# 160:	learn: -0.8928115	total: 22.5s	remaining: 1m 57s
# 161:	learn: -0.8820512	total: 22.7s	remaining: 1m 57s
# 162:	learn: -0.8733953	total: 22.8s	remaining: 1m 57s
# 163:	learn: -0.8702703	total: 22.9s	remaining: 1m 56s
# 164:	learn: -0.8681344	total: 23.1s	remaining: 1m 56s
# 165:	learn: -0.8637435	total: 23.2s	remaining: 1m 56s
# 166:	learn: -0.8619572	total: 23.3s	remaining: 1m 56s
# 167:	learn: -0.8563944	total: 23.5s	remaining: 1m 56s
# 168:	learn: -0.8543506	total: 23.6s	remaining: 1m 56s
# 169:	learn: -0.8525150	total: 23.7s	remaining: 1m 55s
# 170:	learn: -0.8501946	total: 23.9s	remaining: 1m 55s
# 171:	learn: -0.8478084	total: 24s	remaining: 1m 55s
# 172:	learn: -0.8464536	total: 24.2s	remaining: 1m 55s
# 173:	learn: -0.8376387	total: 24.3s	remaining: 1m 55s
# 174:	learn: -0.8361681	total: 24.4s	remaining: 1m 55s
# 175:	learn: -0.8353089	total: 24.6s	remaining: 1m 54s
# 176:	learn: -0.8326139	total: 24.7s	remaining: 1m 54s
# 177:	learn: -0.8306490	total: 24.8s	remaining: 1m 54s
# 178:	learn: -0.8288215	total: 25s	remaining: 1m 54s
# 179:	learn: -0.8274360	total: 25.1s	remaining: 1m 54s
# 180:	learn: -0.8254484	total: 25.2s	remaining: 1m 54s
# 181:	learn: -0.8240334	total: 25.4s	remaining: 1m 54s
# 182:	learn: -0.8223129	total: 25.5s	remaining: 1m 53s
# 183:	learn: -0.8195541	total: 25.6s	remaining: 1m 53s
# 184:	learn: -0.8168725	total: 25.8s	remaining: 1m 53s
# 185:	learn: -0.8159410	total: 25.9s	remaining: 1m 53s
# 186:	learn: -0.8144052	total: 26.1s	remaining: 1m 53s
# 187:	learn: -0.8089925	total: 26.2s	remaining: 1m 53s
# 188:	learn: -0.8066486	total: 26.3s	remaining: 1m 52s
# 189:	learn: -0.8056674	total: 26.5s	remaining: 1m 52s
# 190:	learn: -0.8023431	total: 26.6s	remaining: 1m 52s
# 191:	learn: -0.8011405	total: 26.7s	remaining: 1m 52s
# 192:	learn: -0.7996660	total: 26.9s	remaining: 1m 52s
# 193:	learn: -0.7939992	total: 27s	remaining: 1m 52s
# 194:	learn: -0.7926399	total: 27.1s	remaining: 1m 52s
# 195:	learn: -0.7911172	total: 27.3s	remaining: 1m 51s
# 196:	learn: -0.7901878	total: 27.4s	remaining: 1m 51s
# 197:	learn: -0.7890141	total: 27.6s	remaining: 1m 51s
# 198:	learn: -0.7878498	total: 27.7s	remaining: 1m 51s
# 199:	learn: -0.7863207	total: 27.8s	remaining: 1m 51s
# 200:	learn: -0.7847433	total: 28s	remaining: 1m 51s
# 201:	learn: -0.7827640	total: 28.1s	remaining: 1m 50s
# 202:	learn: -0.7816575	total: 28.2s	remaining: 1m 50s
# 203:	learn: -0.7804762	total: 28.4s	remaining: 1m 50s
# 204:	learn: -0.7781583	total: 28.5s	remaining: 1m 50s
# 205:	learn: -0.7771896	total: 28.6s	remaining: 1m 50s
# 206:	learn: -0.7759305	total: 28.8s	remaining: 1m 50s
# 207:	learn: -0.7751231	total: 28.9s	remaining: 1m 50s
# 208:	learn: -0.7730164	total: 29s	remaining: 1m 49s
# 209:	learn: -0.7721238	total: 29.2s	remaining: 1m 49s
# 210:	learn: -0.7710651	total: 29.3s	remaining: 1m 49s
# 211:	learn: -0.7699221	total: 29.5s	remaining: 1m 49s
# 212:	learn: -0.7673399	total: 29.6s	remaining: 1m 49s
# 213:	learn: -0.7663617	total: 29.7s	remaining: 1m 49s
# 214:	learn: -0.7655681	total: 29.9s	remaining: 1m 49s
# 215:	learn: -0.7638912	total: 30s	remaining: 1m 48s
# 216:	learn: -0.7617267	total: 30.2s	remaining: 1m 48s
# 217:	learn: -0.7601210	total: 30.3s	remaining: 1m 48s
# 218:	learn: -0.7567127	total: 30.4s	remaining: 1m 48s
# 219:	learn: -0.7554101	total: 30.6s	remaining: 1m 48s
# 220:	learn: -0.7544151	total: 30.7s	remaining: 1m 48s
# 221:	learn: -0.7533945	total: 30.8s	remaining: 1m 48s
# 222:	learn: -0.7523289	total: 31s	remaining: 1m 47s
# 223:	learn: -0.7515962	total: 31.1s	remaining: 1m 47s
# 224:	learn: -0.7509571	total: 31.3s	remaining: 1m 47s
# 225:	learn: -0.7453543	total: 31.4s	remaining: 1m 47s
# 226:	learn: -0.7447190	total: 31.5s	remaining: 1m 47s
# 227:	learn: -0.7432953	total: 31.7s	remaining: 1m 47s
# 228:	learn: -0.7421140	total: 31.8s	remaining: 1m 47s
# 229:	learn: -0.7407294	total: 31.9s	remaining: 1m 46s
# 230:	learn: -0.7383802	total: 32.1s	remaining: 1m 46s
# 231:	learn: -0.7362014	total: 32.2s	remaining: 1m 46s
# 232:	learn: -0.7317363	total: 32.3s	remaining: 1m 46s
# 233:	learn: -0.7248602	total: 32.5s	remaining: 1m 46s
# 234:	learn: -0.7235800	total: 32.6s	remaining: 1m 46s
# 235:	learn: -0.7225142	total: 32.8s	remaining: 1m 46s
# 236:	learn: -0.7194103	total: 32.9s	remaining: 1m 45s
# 237:	learn: -0.7169517	total: 33s	remaining: 1m 45s
# 238:	learn: -0.7128202	total: 33.2s	remaining: 1m 45s
# 239:	learn: -0.7107106	total: 33.3s	remaining: 1m 45s
# 240:	learn: -0.7084368	total: 33.5s	remaining: 1m 45s
# 241:	learn: -0.7027696	total: 33.6s	remaining: 1m 45s
# 242:	learn: -0.7015219	total: 33.7s	remaining: 1m 45s
# 243:	learn: -0.7003802	total: 33.9s	remaining: 1m 44s
# 244:	learn: -0.6982122	total: 34s	remaining: 1m 44s
# 245:	learn: -0.6973794	total: 34.1s	remaining: 1m 44s
# 246:	learn: -0.6811795	total: 34.3s	remaining: 1m 44s
# 247:	learn: -0.6793149	total: 34.4s	remaining: 1m 44s
# 248:	learn: -0.6736325	total: 34.6s	remaining: 1m 44s
# 249:	learn: -0.6709038	total: 34.7s	remaining: 1m 44s
# 250:	learn: -0.6685814	total: 34.8s	remaining: 1m 43s
# 251:	learn: -0.6657290	total: 35s	remaining: 1m 43s
# 252:	learn: -0.6639227	total: 35.1s	remaining: 1m 43s
# 253:	learn: -0.6622509	total: 35.2s	remaining: 1m 43s
# 254:	learn: -0.6603078	total: 35.4s	remaining: 1m 43s
# 255:	learn: -0.6584458	total: 35.5s	remaining: 1m 43s
# 256:	learn: -0.6572231	total: 35.6s	remaining: 1m 43s
# 257:	learn: -0.6559238	total: 35.8s	remaining: 1m 42s
# 258:	learn: -0.6550207	total: 35.9s	remaining: 1m 42s
# 259:	learn: -0.6543629	total: 36.1s	remaining: 1m 42s
# 260:	learn: -0.6529249	total: 36.2s	remaining: 1m 42s
# 261:	learn: -0.6519136	total: 36.3s	remaining: 1m 42s
# 262:	learn: -0.6507542	total: 36.5s	remaining: 1m 42s
# 263:	learn: -0.6490095	total: 36.6s	remaining: 1m 42s
# 264:	learn: -0.6484042	total: 36.7s	remaining: 1m 41s
# 265:	learn: -0.6475206	total: 36.9s	remaining: 1m 41s
# 266:	learn: -0.6467727	total: 37s	remaining: 1m 41s
# 267:	learn: -0.6460254	total: 37.2s	remaining: 1m 41s
# 268:	learn: -0.6451414	total: 37.3s	remaining: 1m 41s
# 269:	learn: -0.6431485	total: 37.4s	remaining: 1m 41s
# 270:	learn: -0.6422489	total: 37.6s	remaining: 1m 41s
# 271:	learn: -0.6362671	total: 37.7s	remaining: 1m 40s
# 272:	learn: -0.6209607	total: 37.8s	remaining: 1m 40s
# 273:	learn: -0.6191319	total: 38s	remaining: 1m 40s
# 274:	learn: -0.6166153	total: 38.1s	remaining: 1m 40s
# 275:	learn: -0.6114907	total: 38.3s	remaining: 1m 40s
# 276:	learn: -0.6101121	total: 38.4s	remaining: 1m 40s
# 277:	learn: -0.6081451	total: 38.5s	remaining: 1m 40s
# 278:	learn: -0.6037961	total: 38.7s	remaining: 1m 39s
# 279:	learn: -0.6024996	total: 38.8s	remaining: 1m 39s
# 280:	learn: -0.5973408	total: 38.9s	remaining: 1m 39s
# 281:	learn: -0.5937037	total: 39.1s	remaining: 1m 39s
# 282:	learn: -0.5908557	total: 39.2s	remaining: 1m 39s
# 283:	learn: -0.5901264	total: 39.4s	remaining: 1m 39s
# 284:	learn: -0.5868211	total: 39.5s	remaining: 1m 39s
# 285:	learn: -0.5824950	total: 39.6s	remaining: 1m 38s
# 286:	learn: -0.5808333	total: 39.8s	remaining: 1m 38s
# 287:	learn: -0.5775456	total: 39.9s	remaining: 1m 38s
# 288:	learn: -0.5726242	total: 40.1s	remaining: 1m 38s
# 289:	learn: -0.5715373	total: 40.2s	remaining: 1m 38s
# 290:	learn: -0.5665563	total: 40.3s	remaining: 1m 38s
# 291:	learn: -0.5566391	total: 40.5s	remaining: 1m 38s
# 292:	learn: -0.5544942	total: 40.6s	remaining: 1m 37s
# 293:	learn: -0.5513156	total: 40.7s	remaining: 1m 37s
# 294:	learn: -0.5481805	total: 40.9s	remaining: 1m 37s
# 295:	learn: -0.5456780	total: 41s	remaining: 1m 37s
# 296:	learn: -0.5437264	total: 41.2s	remaining: 1m 37s
# 297:	learn: -0.5399667	total: 41.3s	remaining: 1m 37s
# 298:	learn: -0.5390407	total: 41.4s	remaining: 1m 37s
# 299:	learn: -0.5362334	total: 41.6s	remaining: 1m 36s
# 300:	learn: -0.5350646	total: 41.7s	remaining: 1m 36s
# 301:	learn: -0.5336100	total: 41.8s	remaining: 1m 36s
# 302:	learn: -0.5289295	total: 42s	remaining: 1m 36s
# 303:	learn: -0.5281908	total: 42.1s	remaining: 1m 36s
# 304:	learn: -0.5272499	total: 42.3s	remaining: 1m 36s
# 305:	learn: -0.5253810	total: 42.4s	remaining: 1m 36s
# 306:	learn: -0.5207092	total: 42.5s	remaining: 1m 36s
# 307:	learn: -0.5198567	total: 42.7s	remaining: 1m 35s
# 308:	learn: -0.5177961	total: 42.8s	remaining: 1m 35s
# 309:	learn: -0.5157449	total: 42.9s	remaining: 1m 35s
# 310:	learn: -0.5145407	total: 43.1s	remaining: 1m 35s
# 311:	learn: -0.5110774	total: 43.2s	remaining: 1m 35s
# 312:	learn: -0.5091102	total: 43.4s	remaining: 1m 35s
# 313:	learn: -0.5082062	total: 43.5s	remaining: 1m 35s
# 314:	learn: -0.5073750	total: 43.6s	remaining: 1m 34s
# 315:	learn: -0.5065820	total: 43.8s	remaining: 1m 34s
# 316:	learn: -0.5056279	total: 43.9s	remaining: 1m 34s
# 317:	learn: -0.4998137	total: 44s	remaining: 1m 34s
# 318:	learn: -0.4988749	total: 44.2s	remaining: 1m 34s
# 319:	learn: -0.4962480	total: 44.3s	remaining: 1m 34s
# 320:	learn: -0.4952569	total: 44.5s	remaining: 1m 34s
# 321:	learn: -0.4947426	total: 44.6s	remaining: 1m 33s
# 322:	learn: -0.4930848	total: 44.8s	remaining: 1m 33s
# 323:	learn: -0.4892802	total: 44.9s	remaining: 1m 33s
# 324:	learn: -0.4883930	total: 45s	remaining: 1m 33s
# 325:	learn: -0.4847426	total: 45.2s	remaining: 1m 33s
# 326:	learn: -0.4792466	total: 45.3s	remaining: 1m 33s
# 327:	learn: -0.4771525	total: 45.4s	remaining: 1m 33s
# 328:	learn: -0.4726499	total: 45.6s	remaining: 1m 32s
# 329:	learn: -0.4716750	total: 45.7s	remaining: 1m 32s
# 330:	learn: -0.4707992	total: 45.9s	remaining: 1m 32s
# 331:	learn: -0.4597432	total: 46s	remaining: 1m 32s
# 332:	learn: -0.4588508	total: 46.1s	remaining: 1m 32s
# 333:	learn: -0.4525878	total: 46.3s	remaining: 1m 32s
# 334:	learn: -0.4511334	total: 46.4s	remaining: 1m 32s
# 335:	learn: -0.4499524	total: 46.6s	remaining: 1m 32s
# 336:	learn: -0.4489965	total: 46.7s	remaining: 1m 31s
# 337:	learn: -0.4467981	total: 46.8s	remaining: 1m 31s
# 338:	learn: -0.4452061	total: 47s	remaining: 1m 31s
# 339:	learn: -0.4439845	total: 47.1s	remaining: 1m 31s
# 340:	learn: -0.4420748	total: 47.3s	remaining: 1m 31s
# 341:	learn: -0.4408435	total: 47.4s	remaining: 1m 31s
# 342:	learn: -0.4400445	total: 47.5s	remaining: 1m 31s
# 343:	learn: -0.4391968	total: 47.7s	remaining: 1m 30s
# 344:	learn: -0.4382959	total: 47.8s	remaining: 1m 30s
# 345:	learn: -0.4375412	total: 47.9s	remaining: 1m 30s
# 346:	learn: -0.4360541	total: 48.1s	remaining: 1m 30s
# 347:	learn: -0.4349797	total: 48.2s	remaining: 1m 30s
# 348:	learn: -0.4317102	total: 48.4s	remaining: 1m 30s
# 349:	learn: -0.4304880	total: 48.5s	remaining: 1m 30s
# 350:	learn: -0.4298834	total: 48.6s	remaining: 1m 29s
# 351:	learn: -0.4264176	total: 48.8s	remaining: 1m 29s
# 352:	learn: -0.4240392	total: 48.9s	remaining: 1m 29s
# 353:	learn: -0.4234015	total: 49s	remaining: 1m 29s
# 354:	learn: -0.4206293	total: 49.2s	remaining: 1m 29s
# 355:	learn: -0.4198823	total: 49.3s	remaining: 1m 29s
# 356:	learn: -0.4188261	total: 49.5s	remaining: 1m 29s
# 357:	learn: -0.4175920	total: 49.6s	remaining: 1m 28s
# 358:	learn: -0.4155649	total: 49.7s	remaining: 1m 28s
# 359:	learn: -0.4140804	total: 49.9s	remaining: 1m 28s
# 360:	learn: -0.4132189	total: 50s	remaining: 1m 28s
# 361:	learn: -0.4094531	total: 50.2s	remaining: 1m 28s
# 362:	learn: -0.4085030	total: 50.3s	remaining: 1m 28s
# 363:	learn: -0.4073820	total: 50.4s	remaining: 1m 28s
# 364:	learn: -0.4061120	total: 50.6s	remaining: 1m 28s
# 365:	learn: -0.4020279	total: 50.7s	remaining: 1m 27s
# 366:	learn: -0.4015073	total: 50.9s	remaining: 1m 27s
# 367:	learn: -0.4005447	total: 51s	remaining: 1m 27s
# 368:	learn: -0.3988730	total: 51.1s	remaining: 1m 27s
# 369:	learn: -0.3974919	total: 51.3s	remaining: 1m 27s
# 370:	learn: -0.3964871	total: 51.4s	remaining: 1m 27s
# 371:	learn: -0.3953195	total: 51.5s	remaining: 1m 27s
# 372:	learn: -0.3947279	total: 51.7s	remaining: 1m 26s
# 373:	learn: -0.3933345	total: 51.8s	remaining: 1m 26s
# 374:	learn: -0.3929509	total: 52s	remaining: 1m 26s
# 375:	learn: -0.3919416	total: 52.1s	remaining: 1m 26s
# 376:	learn: -0.3912189	total: 52.2s	remaining: 1m 26s
# 377:	learn: -0.3899148	total: 52.4s	remaining: 1m 26s
# 378:	learn: -0.3869067	total: 52.5s	remaining: 1m 26s
# 379:	learn: -0.3827416	total: 52.7s	remaining: 1m 25s
# 380:	learn: -0.3822206	total: 52.8s	remaining: 1m 25s
# 381:	learn: -0.3778411	total: 52.9s	remaining: 1m 25s
# 382:	learn: -0.3767992	total: 53.1s	remaining: 1m 25s
# 383:	learn: -0.3758697	total: 53.2s	remaining: 1m 25s
# 384:	learn: -0.3749790	total: 53.3s	remaining: 1m 25s
# 385:	learn: -0.3741741	total: 53.5s	remaining: 1m 25s
# 386:	learn: -0.3732098	total: 53.6s	remaining: 1m 24s
# 387:	learn: -0.3719205	total: 53.8s	remaining: 1m 24s
# 388:	learn: -0.3680558	total: 53.9s	remaining: 1m 24s
# 389:	learn: -0.3677126	total: 54.1s	remaining: 1m 24s
# 390:	learn: -0.3673744	total: 54.2s	remaining: 1m 24s
# 391:	learn: -0.3657358	total: 54.3s	remaining: 1m 24s
# 392:	learn: -0.3619228	total: 54.5s	remaining: 1m 24s
# 393:	learn: -0.3604888	total: 54.6s	remaining: 1m 23s
# 394:	learn: -0.3589374	total: 54.7s	remaining: 1m 23s
# 395:	learn: -0.3581155	total: 54.9s	remaining: 1m 23s
# 396:	learn: -0.3575462	total: 55s	remaining: 1m 23s
# 397:	learn: -0.3567743	total: 55.2s	remaining: 1m 23s
# 398:	learn: -0.3549278	total: 55.3s	remaining: 1m 23s
# 399:	learn: -0.3520529	total: 55.4s	remaining: 1m 23s
# 400:	learn: -0.3514821	total: 55.6s	remaining: 1m 23s
# 401:	learn: -0.3504697	total: 55.7s	remaining: 1m 22s
# 402:	learn: -0.3484597	total: 55.8s	remaining: 1m 22s
# 403:	learn: -0.3474053	total: 56s	remaining: 1m 22s
# 404:	learn: -0.3469789	total: 56.1s	remaining: 1m 22s
# 405:	learn: -0.3457006	total: 56.3s	remaining: 1m 22s
# 406:	learn: -0.3439152	total: 56.4s	remaining: 1m 22s
# 407:	learn: -0.3434122	total: 56.5s	remaining: 1m 22s
# 408:	learn: -0.3430262	total: 56.7s	remaining: 1m 21s
# 409:	learn: -0.3321888	total: 56.8s	remaining: 1m 21s
# 410:	learn: -0.3314328	total: 57s	remaining: 1m 21s
# 411:	learn: -0.3309569	total: 57.1s	remaining: 1m 21s
# 412:	learn: -0.3303101	total: 57.2s	remaining: 1m 21s
# 413:	learn: -0.3274682	total: 57.4s	remaining: 1m 21s
# 414:	learn: -0.3254603	total: 57.5s	remaining: 1m 21s
# 415:	learn: -0.3241917	total: 57.6s	remaining: 1m 20s
# 416:	learn: -0.3231730	total: 57.8s	remaining: 1m 20s
# 417:	learn: -0.3227222	total: 57.9s	remaining: 1m 20s
# 418:	learn: -0.3221875	total: 58s	remaining: 1m 20s
# 419:	learn: -0.3206450	total: 58.2s	remaining: 1m 20s
# 420:	learn: -0.3197970	total: 58.3s	remaining: 1m 20s
# 421:	learn: -0.3183360	total: 58.5s	remaining: 1m 20s
# 422:	learn: -0.3177766	total: 58.6s	remaining: 1m 19s
# 423:	learn: -0.3111257	total: 58.7s	remaining: 1m 19s
# 424:	learn: -0.3101701	total: 58.9s	remaining: 1m 19s
# 425:	learn: -0.3093438	total: 59s	remaining: 1m 19s
# 426:	learn: -0.3086498	total: 59.2s	remaining: 1m 19s
# 427:	learn: -0.3076997	total: 59.3s	remaining: 1m 19s
# 428:	learn: -0.3066536	total: 59.4s	remaining: 1m 19s
# 429:	learn: -0.3055622	total: 59.6s	remaining: 1m 18s
# 430:	learn: -0.3037763	total: 59.7s	remaining: 1m 18s
# 431:	learn: -0.3003612	total: 59.8s	remaining: 1m 18s
# 432:	learn: -0.2968082	total: 60s	remaining: 1m 18s
# 433:	learn: -0.2945924	total: 1m	remaining: 1m 18s
# 434:	learn: -0.2942803	total: 1m	remaining: 1m 18s
# 435:	learn: -0.2927682	total: 1m	remaining: 1m 18s
# 436:	learn: -0.2913019	total: 1m	remaining: 1m 17s
# 437:	learn: -0.2902364	total: 1m	remaining: 1m 17s
# 438:	learn: -0.2895554	total: 1m	remaining: 1m 17s
# 439:	learn: -0.2867824	total: 1m	remaining: 1m 17s
# 440:	learn: -0.2861832	total: 1m 1s	remaining: 1m 17s
# 441:	learn: -0.2857372	total: 1m 1s	remaining: 1m 17s
# 442:	learn: -0.2852321	total: 1m 1s	remaining: 1m 17s
# 443:	learn: -0.2844041	total: 1m 1s	remaining: 1m 17s
# 444:	learn: -0.2813734	total: 1m 1s	remaining: 1m 16s
# 445:	learn: -0.2800244	total: 1m 1s	remaining: 1m 16s
# 446:	learn: -0.2790180	total: 1m 1s	remaining: 1m 16s
# 447:	learn: -0.2757302	total: 1m 2s	remaining: 1m 16s
# 448:	learn: -0.2752279	total: 1m 2s	remaining: 1m 16s
# 449:	learn: -0.2743829	total: 1m 2s	remaining: 1m 16s
# 450:	learn: -0.2738176	total: 1m 2s	remaining: 1m 16s
# 451:	learn: -0.2671298	total: 1m 2s	remaining: 1m 15s
# 452:	learn: -0.2662318	total: 1m 2s	remaining: 1m 15s
# 453:	learn: -0.2648933	total: 1m 2s	remaining: 1m 15s
# 454:	learn: -0.2643907	total: 1m 3s	remaining: 1m 15s
# 455:	learn: -0.2635357	total: 1m 3s	remaining: 1m 15s
# 456:	learn: -0.2628091	total: 1m 3s	remaining: 1m 15s
# 457:	learn: -0.2596470	total: 1m 3s	remaining: 1m 15s
# 458:	learn: -0.2592147	total: 1m 3s	remaining: 1m 14s
# 459:	learn: -0.2588351	total: 1m 3s	remaining: 1m 14s
# 460:	learn: -0.2581242	total: 1m 3s	remaining: 1m 14s
# 461:	learn: -0.2578455	total: 1m 3s	remaining: 1m 14s
# 462:	learn: -0.2575340	total: 1m 4s	remaining: 1m 14s
# 463:	learn: -0.2572723	total: 1m 4s	remaining: 1m 14s
# 464:	learn: -0.2568998	total: 1m 4s	remaining: 1m 14s
# 465:	learn: -0.2562517	total: 1m 4s	remaining: 1m 13s
# 466:	learn: -0.2559421	total: 1m 4s	remaining: 1m 13s
# 467:	learn: -0.2553027	total: 1m 4s	remaining: 1m 13s
# 468:	learn: -0.2546087	total: 1m 4s	remaining: 1m 13s
# 469:	learn: -0.2518467	total: 1m 5s	remaining: 1m 13s
# 470:	learn: -0.2515093	total: 1m 5s	remaining: 1m 13s
# 471:	learn: -0.2510769	total: 1m 5s	remaining: 1m 13s
# 472:	learn: -0.2506028	total: 1m 5s	remaining: 1m 13s
# 473:	learn: -0.2499486	total: 1m 5s	remaining: 1m 12s
# 474:	learn: -0.2497052	total: 1m 5s	remaining: 1m 12s
# 475:	learn: -0.2493299	total: 1m 5s	remaining: 1m 12s
# 476:	learn: -0.2490095	total: 1m 6s	remaining: 1m 12s
# 477:	learn: -0.2485224	total: 1m 6s	remaining: 1m 12s
# 478:	learn: -0.2483323	total: 1m 6s	remaining: 1m 12s
# 479:	learn: -0.2479304	total: 1m 6s	remaining: 1m 12s
# 480:	learn: -0.2472594	total: 1m 6s	remaining: 1m 11s
# 481:	learn: -0.2469025	total: 1m 6s	remaining: 1m 11s
# 482:	learn: -0.2458305	total: 1m 6s	remaining: 1m 11s
# 483:	learn: -0.2450662	total: 1m 7s	remaining: 1m 11s
# 484:	learn: -0.2428927	total: 1m 7s	remaining: 1m 11s
# 485:	learn: -0.2427200	total: 1m 7s	remaining: 1m 11s
# 486:	learn: -0.2420840	total: 1m 7s	remaining: 1m 11s
# 487:	learn: -0.2412133	total: 1m 7s	remaining: 1m 10s
# 488:	learn: -0.2409661	total: 1m 7s	remaining: 1m 10s
# 489:	learn: -0.2405991	total: 1m 7s	remaining: 1m 10s
# 490:	learn: -0.2393077	total: 1m 8s	remaining: 1m 10s
# 491:	learn: -0.2385899	total: 1m 8s	remaining: 1m 10s
# 492:	learn: -0.2383764	total: 1m 8s	remaining: 1m 10s
# 493:	learn: -0.2373935	total: 1m 8s	remaining: 1m 10s
# 494:	learn: -0.2365361	total: 1m 8s	remaining: 1m 9s
# 495:	learn: -0.2355674	total: 1m 8s	remaining: 1m 9s
# 496:	learn: -0.2343282	total: 1m 8s	remaining: 1m 9s
# 497:	learn: -0.2336728	total: 1m 9s	remaining: 1m 9s
# 498:	learn: -0.2332791	total: 1m 9s	remaining: 1m 9s
# 499:	learn: -0.2330031	total: 1m 9s	remaining: 1m 9s
# 500:	learn: -0.2321069	total: 1m 9s	remaining: 1m 9s
# 501:	learn: -0.2317416	total: 1m 9s	remaining: 1m 9s
# 502:	learn: -0.2315026	total: 1m 9s	remaining: 1m 8s
# 503:	learn: -0.2314075	total: 1m 9s	remaining: 1m 8s
# 504:	learn: -0.2301893	total: 1m 9s	remaining: 1m 8s
# 505:	learn: -0.2299669	total: 1m 10s	remaining: 1m 8s
# 506:	learn: -0.2296236	total: 1m 10s	remaining: 1m 8s
# 507:	learn: -0.2292280	total: 1m 10s	remaining: 1m 8s
# 508:	learn: -0.2290460	total: 1m 10s	remaining: 1m 8s
# 509:	learn: -0.2284624	total: 1m 10s	remaining: 1m 7s
# 510:	learn: -0.2282513	total: 1m 10s	remaining: 1m 7s
# 511:	learn: -0.2279776	total: 1m 10s	remaining: 1m 7s
# 512:	learn: -0.2272167	total: 1m 11s	remaining: 1m 7s
# 513:	learn: -0.2270109	total: 1m 11s	remaining: 1m 7s
# 514:	learn: -0.2264154	total: 1m 11s	remaining: 1m 7s
# 515:	learn: -0.2259106	total: 1m 11s	remaining: 1m 7s
# 516:	learn: -0.2251109	total: 1m 11s	remaining: 1m 6s
# 517:	learn: -0.2247394	total: 1m 11s	remaining: 1m 6s
# 518:	learn: -0.2243922	total: 1m 11s	remaining: 1m 6s
# 519:	learn: -0.2238261	total: 1m 12s	remaining: 1m 6s
# 520:	learn: -0.2234402	total: 1m 12s	remaining: 1m 6s
# 521:	learn: -0.2227900	total: 1m 12s	remaining: 1m 6s
# 522:	learn: -0.2225107	total: 1m 12s	remaining: 1m 6s
# 523:	learn: -0.2218502	total: 1m 12s	remaining: 1m 5s
# 524:	learn: -0.2211878	total: 1m 12s	remaining: 1m 5s
# 525:	learn: -0.2210734	total: 1m 12s	remaining: 1m 5s
# 526:	learn: -0.2206921	total: 1m 13s	remaining: 1m 5s
# 527:	learn: -0.2197456	total: 1m 13s	remaining: 1m 5s
# 528:	learn: -0.2193739	total: 1m 13s	remaining: 1m 5s
# 529:	learn: -0.2191821	total: 1m 13s	remaining: 1m 5s
# 530:	learn: -0.2179653	total: 1m 13s	remaining: 1m 4s
# 531:	learn: -0.2176785	total: 1m 13s	remaining: 1m 4s
# 532:	learn: -0.2175115	total: 1m 13s	remaining: 1m 4s
# 533:	learn: -0.2170857	total: 1m 13s	remaining: 1m 4s
# 534:	learn: -0.2167289	total: 1m 14s	remaining: 1m 4s
# 535:	learn: -0.2164097	total: 1m 14s	remaining: 1m 4s
# 536:	learn: -0.2161600	total: 1m 14s	remaining: 1m 4s
# 537:	learn: -0.2156418	total: 1m 14s	remaining: 1m 4s
# 538:	learn: -0.2150336	total: 1m 14s	remaining: 1m 3s
# 539:	learn: -0.2146232	total: 1m 14s	remaining: 1m 3s
# 540:	learn: -0.2141131	total: 1m 14s	remaining: 1m 3s
# 541:	learn: -0.2137429	total: 1m 15s	remaining: 1m 3s
# 542:	learn: -0.2133378	total: 1m 15s	remaining: 1m 3s
# 543:	learn: -0.2131557	total: 1m 15s	remaining: 1m 3s
# 544:	learn: -0.2127904	total: 1m 15s	remaining: 1m 3s
# 545:	learn: -0.2124410	total: 1m 15s	remaining: 1m 2s
# 546:	learn: -0.2122341	total: 1m 15s	remaining: 1m 2s
# 547:	learn: -0.2121027	total: 1m 15s	remaining: 1m 2s
# 548:	learn: -0.2114774	total: 1m 16s	remaining: 1m 2s
# 549:	learn: -0.2109420	total: 1m 16s	remaining: 1m 2s
# 550:	learn: -0.2103500	total: 1m 16s	remaining: 1m 2s
# 551:	learn: -0.2090435	total: 1m 16s	remaining: 1m 2s
# 552:	learn: -0.2088700	total: 1m 16s	remaining: 1m 1s
# 553:	learn: -0.2084481	total: 1m 16s	remaining: 1m 1s
# 554:	learn: -0.2063170	total: 1m 16s	remaining: 1m 1s
# 555:	learn: -0.2054943	total: 1m 17s	remaining: 1m 1s
# 556:	learn: -0.2051901	total: 1m 17s	remaining: 1m 1s
# 557:	learn: -0.2050745	total: 1m 17s	remaining: 1m 1s
# 558:	learn: -0.2042915	total: 1m 17s	remaining: 1m 1s
# 559:	learn: -0.2039689	total: 1m 17s	remaining: 1m
# 560:	learn: -0.2035719	total: 1m 17s	remaining: 1m
# 561:	learn: -0.2027757	total: 1m 17s	remaining: 1m
# 562:	learn: -0.2025093	total: 1m 18s	remaining: 1m
# 563:	learn: -0.2023112	total: 1m 18s	remaining: 1m
# 564:	learn: -0.2021243	total: 1m 18s	remaining: 1m
# 565:	learn: -0.2018046	total: 1m 18s	remaining: 1m
# 566:	learn: -0.2015159	total: 1m 18s	remaining: 1m
# 567:	learn: -0.2013406	total: 1m 18s	remaining: 59.9s
# 568:	learn: -0.2010334	total: 1m 18s	remaining: 59.7s
# 569:	learn: -0.2007822	total: 1m 18s	remaining: 59.6s
# 570:	learn: -0.2002143	total: 1m 19s	remaining: 59.5s
# 571:	learn: -0.2000888	total: 1m 19s	remaining: 59.3s
# 572:	learn: -0.1999516	total: 1m 19s	remaining: 59.2s
# 573:	learn: -0.1994439	total: 1m 19s	remaining: 59s
# 574:	learn: -0.1992653	total: 1m 19s	remaining: 58.9s
# 575:	learn: -0.1989563	total: 1m 19s	remaining: 58.8s
# 576:	learn: -0.1987241	total: 1m 19s	remaining: 58.6s
# 577:	learn: -0.1985051	total: 1m 20s	remaining: 58.5s
# 578:	learn: -0.1974989	total: 1m 20s	remaining: 58.3s
# 579:	learn: -0.1972041	total: 1m 20s	remaining: 58.2s
# 580:	learn: -0.1969232	total: 1m 20s	remaining: 58.1s
# 581:	learn: -0.1967566	total: 1m 20s	remaining: 57.9s
# 582:	learn: -0.1966056	total: 1m 20s	remaining: 57.8s
# 583:	learn: -0.1957696	total: 1m 20s	remaining: 57.6s
# 584:	learn: -0.1956511	total: 1m 21s	remaining: 57.5s
# 585:	learn: -0.1937063	total: 1m 21s	remaining: 57.4s
# 586:	learn: -0.1935262	total: 1m 21s	remaining: 57.2s
# 587:	learn: -0.1921944	total: 1m 21s	remaining: 57.1s
# 588:	learn: -0.1918140	total: 1m 21s	remaining: 57s
# 589:	learn: -0.1915470	total: 1m 21s	remaining: 56.8s
# 590:	learn: -0.1910715	total: 1m 21s	remaining: 56.7s
# 591:	learn: -0.1907435	total: 1m 22s	remaining: 56.5s
# 592:	learn: -0.1906443	total: 1m 22s	remaining: 56.4s
# 593:	learn: -0.1904482	total: 1m 22s	remaining: 56.3s
# 594:	learn: -0.1902542	total: 1m 22s	remaining: 56.1s
# 595:	learn: -0.1900932	total: 1m 22s	remaining: 56s
# 596:	learn: -0.1899197	total: 1m 22s	remaining: 55.8s
# 597:	learn: -0.1897002	total: 1m 22s	remaining: 55.7s
# 598:	learn: -0.1892229	total: 1m 23s	remaining: 55.6s
# 599:	learn: -0.1890075	total: 1m 23s	remaining: 55.4s
# 600:	learn: -0.1879442	total: 1m 23s	remaining: 55.3s
# 601:	learn: -0.1876977	total: 1m 23s	remaining: 55.2s
# 602:	learn: -0.1873060	total: 1m 23s	remaining: 55s
# 603:	learn: -0.1865881	total: 1m 23s	remaining: 54.9s
# 604:	learn: -0.1857083	total: 1m 23s	remaining: 54.7s
# 605:	learn: -0.1851840	total: 1m 23s	remaining: 54.6s
# 606:	learn: -0.1848344	total: 1m 24s	remaining: 54.5s
# 607:	learn: -0.1846649	total: 1m 24s	remaining: 54.3s
# 608:	learn: -0.1845185	total: 1m 24s	remaining: 54.2s
# 609:	learn: -0.1839607	total: 1m 24s	remaining: 54s
# 610:	learn: -0.1836181	total: 1m 24s	remaining: 53.9s
# 611:	learn: -0.1824152	total: 1m 24s	remaining: 53.8s
# 612:	learn: -0.1822874	total: 1m 24s	remaining: 53.6s
# 613:	learn: -0.1813121	total: 1m 25s	remaining: 53.5s
# 614:	learn: -0.1806325	total: 1m 25s	remaining: 53.3s
# 615:	learn: -0.1804101	total: 1m 25s	remaining: 53.2s
# 616:	learn: -0.1802102	total: 1m 25s	remaining: 53.1s
# 617:	learn: -0.1798453	total: 1m 25s	remaining: 52.9s
# 618:	learn: -0.1796930	total: 1m 25s	remaining: 52.8s
# 619:	learn: -0.1789204	total: 1m 25s	remaining: 52.7s
# 620:	learn: -0.1785394	total: 1m 26s	remaining: 52.5s
# 621:	learn: -0.1783314	total: 1m 26s	remaining: 52.4s
# 622:	learn: -0.1781201	total: 1m 26s	remaining: 52.2s
# 623:	learn: -0.1778549	total: 1m 26s	remaining: 52.1s
# 624:	learn: -0.1777472	total: 1m 26s	remaining: 52s
# 625:	learn: -0.1776298	total: 1m 26s	remaining: 51.8s
# 626:	learn: -0.1766179	total: 1m 26s	remaining: 51.7s
# 627:	learn: -0.1761802	total: 1m 27s	remaining: 51.5s
# 628:	learn: -0.1759733	total: 1m 27s	remaining: 51.4s
# 629:	learn: -0.1758039	total: 1m 27s	remaining: 51.3s
# 630:	learn: -0.1757117	total: 1m 27s	remaining: 51.1s
# 631:	learn: -0.1744827	total: 1m 27s	remaining: 51s
# 632:	learn: -0.1743344	total: 1m 27s	remaining: 50.9s
# 633:	learn: -0.1738601	total: 1m 27s	remaining: 50.7s
# 634:	learn: -0.1734716	total: 1m 28s	remaining: 50.6s
# 635:	learn: -0.1733106	total: 1m 28s	remaining: 50.4s
# 636:	learn: -0.1731197	total: 1m 28s	remaining: 50.3s
# 637:	learn: -0.1721227	total: 1m 28s	remaining: 50.2s
# 638:	learn: -0.1716636	total: 1m 28s	remaining: 50s
# 639:	learn: -0.1711887	total: 1m 28s	remaining: 49.9s
# 640:	learn: -0.1710456	total: 1m 28s	remaining: 49.8s
# 641:	learn: -0.1709209	total: 1m 28s	remaining: 49.6s
# 642:	learn: -0.1707257	total: 1m 29s	remaining: 49.5s
# 643:	learn: -0.1706081	total: 1m 29s	remaining: 49.3s
# 644:	learn: -0.1704651	total: 1m 29s	remaining: 49.2s
# 645:	learn: -0.1700108	total: 1m 29s	remaining: 49.1s
# 646:	learn: -0.1695685	total: 1m 29s	remaining: 48.9s
# 647:	learn: -0.1693054	total: 1m 29s	remaining: 48.8s
# 648:	learn: -0.1691782	total: 1m 29s	remaining: 48.6s
# 649:	learn: -0.1690058	total: 1m 30s	remaining: 48.5s
# 650:	learn: -0.1687274	total: 1m 30s	remaining: 48.4s
# 651:	learn: -0.1686283	total: 1m 30s	remaining: 48.2s
# 652:	learn: -0.1682159	total: 1m 30s	remaining: 48.1s
# 653:	learn: -0.1679757	total: 1m 30s	remaining: 47.9s
# 654:	learn: -0.1678910	total: 1m 30s	remaining: 47.8s
# 655:	learn: -0.1674743	total: 1m 30s	remaining: 47.7s
# 656:	learn: -0.1671957	total: 1m 31s	remaining: 47.5s
# 657:	learn: -0.1670318	total: 1m 31s	remaining: 47.4s
# 658:	learn: -0.1664741	total: 1m 31s	remaining: 47.3s
# 659:	learn: -0.1661464	total: 1m 31s	remaining: 47.1s
# 660:	learn: -0.1658870	total: 1m 31s	remaining: 47s
# 661:	learn: -0.1657884	total: 1m 31s	remaining: 46.8s
# 662:	learn: -0.1656610	total: 1m 31s	remaining: 46.7s
# 663:	learn: -0.1655374	total: 1m 32s	remaining: 46.6s
# 664:	learn: -0.1653072	total: 1m 32s	remaining: 46.4s
# 665:	learn: -0.1652436	total: 1m 32s	remaining: 46.3s
# 666:	learn: -0.1651008	total: 1m 32s	remaining: 46.1s
# 667:	learn: -0.1649762	total: 1m 32s	remaining: 46s
# 668:	learn: -0.1645016	total: 1m 32s	remaining: 45.9s
# 669:	learn: -0.1641953	total: 1m 32s	remaining: 45.7s
# 670:	learn: -0.1640846	total: 1m 32s	remaining: 45.6s
# 671:	learn: -0.1640178	total: 1m 33s	remaining: 45.5s
# 672:	learn: -0.1637818	total: 1m 33s	remaining: 45.3s
# 673:	learn: -0.1635907	total: 1m 33s	remaining: 45.2s
# 674:	learn: -0.1635006	total: 1m 33s	remaining: 45s
# 675:	learn: -0.1633021	total: 1m 33s	remaining: 44.9s
# 676:	learn: -0.1630223	total: 1m 33s	remaining: 44.8s
# 677:	learn: -0.1629446	total: 1m 33s	remaining: 44.6s
# 678:	learn: -0.1626999	total: 1m 34s	remaining: 44.5s
# 679:	learn: -0.1624158	total: 1m 34s	remaining: 44.4s
# 680:	learn: -0.1620648	total: 1m 34s	remaining: 44.2s
# 681:	learn: -0.1618818	total: 1m 34s	remaining: 44.1s
# 682:	learn: -0.1618078	total: 1m 34s	remaining: 43.9s
# 683:	learn: -0.1613673	total: 1m 34s	remaining: 43.8s
# 684:	learn: -0.1610732	total: 1m 34s	remaining: 43.7s
# 685:	learn: -0.1609094	total: 1m 35s	remaining: 43.5s
# 686:	learn: -0.1600703	total: 1m 35s	remaining: 43.4s
# 687:	learn: -0.1596903	total: 1m 35s	remaining: 43.3s
# 688:	learn: -0.1595071	total: 1m 35s	remaining: 43.1s
# 689:	learn: -0.1594154	total: 1m 35s	remaining: 43s
# 690:	learn: -0.1588859	total: 1m 35s	remaining: 42.8s
# 691:	learn: -0.1588062	total: 1m 35s	remaining: 42.7s
# 692:	learn: -0.1587108	total: 1m 36s	remaining: 42.6s
# 693:	learn: -0.1586056	total: 1m 36s	remaining: 42.4s
# 694:	learn: -0.1579517	total: 1m 36s	remaining: 42.3s
# 695:	learn: -0.1577337	total: 1m 36s	remaining: 42.2s
# 696:	learn: -0.1574714	total: 1m 36s	remaining: 42s
# 697:	learn: -0.1573389	total: 1m 36s	remaining: 41.9s
# 698:	learn: -0.1571201	total: 1m 36s	remaining: 41.7s
# 699:	learn: -0.1569404	total: 1m 37s	remaining: 41.6s
# 700:	learn: -0.1566659	total: 1m 37s	remaining: 41.5s
# 701:	learn: -0.1562958	total: 1m 37s	remaining: 41.3s
# 702:	learn: -0.1561774	total: 1m 37s	remaining: 41.2s
# 703:	learn: -0.1559197	total: 1m 37s	remaining: 41s
# 704:	learn: -0.1558615	total: 1m 37s	remaining: 40.9s
# 705:	learn: -0.1557014	total: 1m 37s	remaining: 40.8s
# 706:	learn: -0.1555325	total: 1m 38s	remaining: 40.6s
# 707:	learn: -0.1551072	total: 1m 38s	remaining: 40.5s
# 708:	learn: -0.1550356	total: 1m 38s	remaining: 40.4s
# 709:	learn: -0.1548663	total: 1m 38s	remaining: 40.2s
# 710:	learn: -0.1543299	total: 1m 38s	remaining: 40.1s
# 711:	learn: -0.1541921	total: 1m 38s	remaining: 39.9s
# 712:	learn: -0.1541419	total: 1m 38s	remaining: 39.8s
# 713:	learn: -0.1540000	total: 1m 39s	remaining: 39.7s
# 714:	learn: -0.1538967	total: 1m 39s	remaining: 39.5s
# 715:	learn: -0.1537773	total: 1m 39s	remaining: 39.4s
# 716:	learn: -0.1535348	total: 1m 39s	remaining: 39.3s
# 717:	learn: -0.1529201	total: 1m 39s	remaining: 39.1s
# 718:	learn: -0.1527461	total: 1m 39s	remaining: 39s
# 719:	learn: -0.1526162	total: 1m 39s	remaining: 38.8s
# 720:	learn: -0.1524416	total: 1m 40s	remaining: 38.7s
# 721:	learn: -0.1522654	total: 1m 40s	remaining: 38.6s
# 722:	learn: -0.1521258	total: 1m 40s	remaining: 38.4s
# 723:	learn: -0.1520469	total: 1m 40s	remaining: 38.3s
# 724:	learn: -0.1518357	total: 1m 40s	remaining: 38.1s
# 725:	learn: -0.1517470	total: 1m 40s	remaining: 38s
# 726:	learn: -0.1514774	total: 1m 40s	remaining: 37.9s
# 727:	learn: -0.1505212	total: 1m 40s	remaining: 37.7s
# 728:	learn: -0.1502110	total: 1m 41s	remaining: 37.6s
# 729:	learn: -0.1499536	total: 1m 41s	remaining: 37.5s
# 730:	learn: -0.1498068	total: 1m 41s	remaining: 37.3s
# 731:	learn: -0.1494884	total: 1m 41s	remaining: 37.2s
# 732:	learn: -0.1493715	total: 1m 41s	remaining: 37s
# 733:	learn: -0.1490404	total: 1m 41s	remaining: 36.9s
# 734:	learn: -0.1489186	total: 1m 41s	remaining: 36.8s
# 735:	learn: -0.1488768	total: 1m 42s	remaining: 36.6s
# 736:	learn: -0.1487484	total: 1m 42s	remaining: 36.5s
# 737:	learn: -0.1485252	total: 1m 42s	remaining: 36.3s
# 738:	learn: -0.1483263	total: 1m 42s	remaining: 36.2s
# 739:	learn: -0.1482168	total: 1m 42s	remaining: 36.1s
# 740:	learn: -0.1481617	total: 1m 42s	remaining: 35.9s
# 741:	learn: -0.1478151	total: 1m 42s	remaining: 35.8s
# 742:	learn: -0.1477180	total: 1m 43s	remaining: 35.7s
# 743:	learn: -0.1475113	total: 1m 43s	remaining: 35.5s
# 744:	learn: -0.1472761	total: 1m 43s	remaining: 35.4s
# 745:	learn: -0.1471848	total: 1m 43s	remaining: 35.2s
# 746:	learn: -0.1471468	total: 1m 43s	remaining: 35.1s
# 747:	learn: -0.1469948	total: 1m 43s	remaining: 35s
# 748:	learn: -0.1468667	total: 1m 43s	remaining: 34.8s
# 749:	learn: -0.1466953	total: 1m 44s	remaining: 34.7s
# 750:	learn: -0.1465665	total: 1m 44s	remaining: 34.5s
# 751:	learn: -0.1464677	total: 1m 44s	remaining: 34.4s
# 752:	learn: -0.1464104	total: 1m 44s	remaining: 34.3s
# 753:	learn: -0.1463724	total: 1m 44s	remaining: 34.1s
# 754:	learn: -0.1463105	total: 1m 44s	remaining: 34s
# 755:	learn: -0.1462390	total: 1m 44s	remaining: 33.8s
# 756:	learn: -0.1460759	total: 1m 45s	remaining: 33.7s
# 757:	learn: -0.1459796	total: 1m 45s	remaining: 33.6s
# 758:	learn: -0.1458474	total: 1m 45s	remaining: 33.4s
# 759:	learn: -0.1457093	total: 1m 45s	remaining: 33.3s
# 760:	learn: -0.1454470	total: 1m 45s	remaining: 33.2s
# 761:	learn: -0.1453452	total: 1m 45s	remaining: 33s
# 762:	learn: -0.1453118	total: 1m 45s	remaining: 32.9s
# 763:	learn: -0.1452417	total: 1m 45s	remaining: 32.7s
# 764:	learn: -0.1449225	total: 1m 46s	remaining: 32.6s
# 765:	learn: -0.1448875	total: 1m 46s	remaining: 32.5s
# 766:	learn: -0.1448352	total: 1m 46s	remaining: 32.3s
# 767:	learn: -0.1446784	total: 1m 46s	remaining: 32.2s
# 768:	learn: -0.1444554	total: 1m 46s	remaining: 32.1s
# 769:	learn: -0.1443849	total: 1m 46s	remaining: 31.9s
# 770:	learn: -0.1443334	total: 1m 46s	remaining: 31.8s
# 771:	learn: -0.1442841	total: 1m 47s	remaining: 31.6s
# 772:	learn: -0.1440024	total: 1m 47s	remaining: 31.5s
# 773:	learn: -0.1439578	total: 1m 47s	remaining: 31.4s
# 774:	learn: -0.1438343	total: 1m 47s	remaining: 31.2s
# 775:	learn: -0.1436659	total: 1m 47s	remaining: 31.1s
# 776:	learn: -0.1435440	total: 1m 47s	remaining: 30.9s
# 777:	learn: -0.1434507	total: 1m 47s	remaining: 30.8s
# 778:	learn: -0.1433711	total: 1m 48s	remaining: 30.7s
# 779:	learn: -0.1432270	total: 1m 48s	remaining: 30.5s
# 780:	learn: -0.1431002	total: 1m 48s	remaining: 30.4s
# 781:	learn: -0.1427831	total: 1m 48s	remaining: 30.2s
# 782:	learn: -0.1427316	total: 1m 48s	remaining: 30.1s
# 783:	learn: -0.1426674	total: 1m 48s	remaining: 30s
# 784:	learn: -0.1421900	total: 1m 48s	remaining: 29.8s
# 785:	learn: -0.1420772	total: 1m 49s	remaining: 29.7s
# 786:	learn: -0.1419874	total: 1m 49s	remaining: 29.6s
# 787:	learn: -0.1418864	total: 1m 49s	remaining: 29.4s
# 788:	learn: -0.1418127	total: 1m 49s	remaining: 29.3s
# 789:	learn: -0.1417498	total: 1m 49s	remaining: 29.1s
# 790:	learn: -0.1417026	total: 1m 49s	remaining: 29s
# 791:	learn: -0.1416542	total: 1m 49s	remaining: 28.9s
# 792:	learn: -0.1415734	total: 1m 50s	remaining: 28.7s
# 793:	learn: -0.1412116	total: 1m 50s	remaining: 28.6s
# 794:	learn: -0.1410963	total: 1m 50s	remaining: 28.4s
# 795:	learn: -0.1410391	total: 1m 50s	remaining: 28.3s
# 796:	learn: -0.1409217	total: 1m 50s	remaining: 28.2s
# 797:	learn: -0.1407986	total: 1m 50s	remaining: 28s
# 798:	learn: -0.1406420	total: 1m 50s	remaining: 27.9s
# 799:	learn: -0.1404683	total: 1m 51s	remaining: 27.8s
# 800:	learn: -0.1404177	total: 1m 51s	remaining: 27.6s
# 801:	learn: -0.1403571	total: 1m 51s	remaining: 27.5s
# 802:	learn: -0.1403194	total: 1m 51s	remaining: 27.3s
# 803:	learn: -0.1402438	total: 1m 51s	remaining: 27.2s
# 804:	learn: -0.1401267	total: 1m 51s	remaining: 27.1s
# 805:	learn: -0.1400743	total: 1m 51s	remaining: 26.9s
# 806:	learn: -0.1399654	total: 1m 51s	remaining: 26.8s
# 807:	learn: -0.1398941	total: 1m 52s	remaining: 26.6s
# 808:	learn: -0.1398625	total: 1m 52s	remaining: 26.5s
# 809:	learn: -0.1398332	total: 1m 52s	remaining: 26.4s
# 810:	learn: -0.1397538	total: 1m 52s	remaining: 26.2s
# 811:	learn: -0.1395356	total: 1m 52s	remaining: 26.1s
# 812:	learn: -0.1394410	total: 1m 52s	remaining: 25.9s
# 813:	learn: -0.1392891	total: 1m 52s	remaining: 25.8s
# 814:	learn: -0.1390293	total: 1m 53s	remaining: 25.7s
# 815:	learn: -0.1389755	total: 1m 53s	remaining: 25.5s
# 816:	learn: -0.1389226	total: 1m 53s	remaining: 25.4s
# 817:	learn: -0.1386038	total: 1m 53s	remaining: 25.3s
# 818:	learn: -0.1385424	total: 1m 53s	remaining: 25.1s
# 819:	learn: -0.1385218	total: 1m 53s	remaining: 25s
# 820:	learn: -0.1384085	total: 1m 53s	remaining: 24.8s
# 821:	learn: -0.1383252	total: 1m 54s	remaining: 24.7s
# 822:	learn: -0.1382636	total: 1m 54s	remaining: 24.6s
# 823:	learn: -0.1381772	total: 1m 54s	remaining: 24.4s
# 824:	learn: -0.1379871	total: 1m 54s	remaining: 24.3s
# 825:	learn: -0.1379203	total: 1m 54s	remaining: 24.1s
# 826:	learn: -0.1378756	total: 1m 54s	remaining: 24s
# 827:	learn: -0.1377479	total: 1m 54s	remaining: 23.9s
# 828:	learn: -0.1377017	total: 1m 55s	remaining: 23.7s
# 829:	learn: -0.1375772	total: 1m 55s	remaining: 23.6s
# 830:	learn: -0.1375372	total: 1m 55s	remaining: 23.5s
# 831:	learn: -0.1374857	total: 1m 55s	remaining: 23.3s
# 832:	learn: -0.1374650	total: 1m 55s	remaining: 23.2s
# 833:	learn: -0.1373989	total: 1m 55s	remaining: 23s
# 834:	learn: -0.1373444	total: 1m 55s	remaining: 22.9s
# 835:	learn: -0.1373043	total: 1m 56s	remaining: 22.8s
# 836:	learn: -0.1372859	total: 1m 56s	remaining: 22.6s
# 837:	learn: -0.1372619	total: 1m 56s	remaining: 22.5s
# 838:	learn: -0.1371249	total: 1m 56s	remaining: 22.4s
# 839:	learn: -0.1369425	total: 1m 56s	remaining: 22.2s
# 840:	learn: -0.1369049	total: 1m 56s	remaining: 22.1s
# 841:	learn: -0.1367053	total: 1m 56s	remaining: 21.9s
# 842:	learn: -0.1366695	total: 1m 57s	remaining: 21.8s
# 843:	learn: -0.1365933	total: 1m 57s	remaining: 21.7s
# 844:	learn: -0.1365563	total: 1m 57s	remaining: 21.5s
# 845:	learn: -0.1364968	total: 1m 57s	remaining: 21.4s
# 846:	learn: -0.1362977	total: 1m 57s	remaining: 21.2s
# 847:	learn: -0.1362792	total: 1m 57s	remaining: 21.1s
# 848:	learn: -0.1361199	total: 1m 57s	remaining: 21s
# 849:	learn: -0.1360273	total: 1m 58s	remaining: 20.8s
# 850:	learn: -0.1359417	total: 1m 58s	remaining: 20.7s
# 851:	learn: -0.1359057	total: 1m 58s	remaining: 20.5s
# 852:	learn: -0.1357738	total: 1m 58s	remaining: 20.4s
# 853:	learn: -0.1357038	total: 1m 58s	remaining: 20.3s
# 854:	learn: -0.1356156	total: 1m 58s	remaining: 20.1s
# 855:	learn: -0.1354213	total: 1m 58s	remaining: 20s
# 856:	learn: -0.1353692	total: 1m 59s	remaining: 19.9s
# 857:	learn: -0.1353104	total: 1m 59s	remaining: 19.7s
# 858:	learn: -0.1351874	total: 1m 59s	remaining: 19.6s
# 859:	learn: -0.1351489	total: 1m 59s	remaining: 19.4s
# 860:	learn: -0.1350583	total: 1m 59s	remaining: 19.3s
# 861:	learn: -0.1350259	total: 1m 59s	remaining: 19.2s
# 862:	learn: -0.1349759	total: 1m 59s	remaining: 19s
# 863:	learn: -0.1349258	total: 1m 59s	remaining: 18.9s
# 864:	learn: -0.1348057	total: 2m	remaining: 18.7s
# 865:	learn: -0.1347842	total: 2m	remaining: 18.6s
# 866:	learn: -0.1346952	total: 2m	remaining: 18.5s
# 867:	learn: -0.1343474	total: 2m	remaining: 18.3s
# 868:	learn: -0.1342266	total: 2m	remaining: 18.2s
# 869:	learn: -0.1338802	total: 2m	remaining: 18.1s
# 870:	learn: -0.1337440	total: 2m	remaining: 17.9s
# 871:	learn: -0.1337173	total: 2m 1s	remaining: 17.8s
# 872:	learn: -0.1336700	total: 2m 1s	remaining: 17.6s
# 873:	learn: -0.1336260	total: 2m 1s	remaining: 17.5s
# 874:	learn: -0.1335853	total: 2m 1s	remaining: 17.4s
# 875:	learn: -0.1335351	total: 2m 1s	remaining: 17.2s
# 876:	learn: -0.1335223	total: 2m 1s	remaining: 17.1s
# 877:	learn: -0.1333944	total: 2m 1s	remaining: 16.9s
# 878:	learn: -0.1333370	total: 2m 2s	remaining: 16.8s
# 879:	learn: -0.1332671	total: 2m 2s	remaining: 16.7s
# 880:	learn: -0.1332096	total: 2m 2s	remaining: 16.5s
# 881:	learn: -0.1331863	total: 2m 2s	remaining: 16.4s
# 882:	learn: -0.1331108	total: 2m 2s	remaining: 16.3s
# 883:	learn: -0.1330703	total: 2m 2s	remaining: 16.1s
# 884:	learn: -0.1330174	total: 2m 2s	remaining: 16s
# 885:	learn: -0.1327567	total: 2m 3s	remaining: 15.8s
# 886:	learn: -0.1327161	total: 2m 3s	remaining: 15.7s
# 887:	learn: -0.1326380	total: 2m 3s	remaining: 15.6s
# 888:	learn: -0.1325841	total: 2m 3s	remaining: 15.4s
# 889:	learn: -0.1325330	total: 2m 3s	remaining: 15.3s
# 890:	learn: -0.1325008	total: 2m 3s	remaining: 15.1s
# 891:	learn: -0.1324701	total: 2m 3s	remaining: 15s
# 892:	learn: -0.1324308	total: 2m 4s	remaining: 14.9s
# 893:	learn: -0.1323912	total: 2m 4s	remaining: 14.7s
# 894:	learn: -0.1323746	total: 2m 4s	remaining: 14.6s
# 895:	learn: -0.1322973	total: 2m 4s	remaining: 14.4s
# 896:	learn: -0.1322423	total: 2m 4s	remaining: 14.3s
# 897:	learn: -0.1319509	total: 2m 4s	remaining: 14.2s
# 898:	learn: -0.1318566	total: 2m 4s	remaining: 14s
# 899:	learn: -0.1317955	total: 2m 5s	remaining: 13.9s
# 900:	learn: -0.1316801	total: 2m 5s	remaining: 13.8s
# 901:	learn: -0.1313925	total: 2m 5s	remaining: 13.6s
# 902:	learn: -0.1313012	total: 2m 5s	remaining: 13.5s
# 903:	learn: -0.1312507	total: 2m 5s	remaining: 13.3s
# 904:	learn: -0.1312236	total: 2m 5s	remaining: 13.2s
# 905:	learn: -0.1311618	total: 2m 5s	remaining: 13.1s
# 906:	learn: -0.1311350	total: 2m 6s	remaining: 12.9s
# 907:	learn: -0.1310982	total: 2m 6s	remaining: 12.8s
# 908:	learn: -0.1309563	total: 2m 6s	remaining: 12.6s
# 909:	learn: -0.1309172	total: 2m 6s	remaining: 12.5s
# 910:	learn: -0.1308945	total: 2m 6s	remaining: 12.4s
# 911:	learn: -0.1308609	total: 2m 6s	remaining: 12.2s
# 912:	learn: -0.1307082	total: 2m 6s	remaining: 12.1s
# 913:	learn: -0.1306237	total: 2m 7s	remaining: 11.9s
# 914:	learn: -0.1306053	total: 2m 7s	remaining: 11.8s
# 915:	learn: -0.1305914	total: 2m 7s	remaining: 11.7s
# 916:	learn: -0.1302340	total: 2m 7s	remaining: 11.5s
# 917:	learn: -0.1301785	total: 2m 7s	remaining: 11.4s
# 918:	learn: -0.1300530	total: 2m 7s	remaining: 11.3s
# 919:	learn: -0.1300297	total: 2m 7s	remaining: 11.1s
# 920:	learn: -0.1298722	total: 2m 7s	remaining: 11s
# 921:	learn: -0.1298104	total: 2m 8s	remaining: 10.8s
# 922:	learn: -0.1296972	total: 2m 8s	remaining: 10.7s
# 923:	learn: -0.1296535	total: 2m 8s	remaining: 10.6s
# 924:	learn: -0.1296329	total: 2m 8s	remaining: 10.4s
# 925:	learn: -0.1295851	total: 2m 8s	remaining: 10.3s
# 926:	learn: -0.1294670	total: 2m 8s	remaining: 10.1s
# 927:	learn: -0.1293651	total: 2m 8s	remaining: 10s
# 928:	learn: -0.1293536	total: 2m 9s	remaining: 9.86s
# 929:	learn: -0.1292286	total: 2m 9s	remaining: 9.73s
# 930:	learn: -0.1291387	total: 2m 9s	remaining: 9.59s
# 931:	learn: -0.1288314	total: 2m 9s	remaining: 9.45s
# 932:	learn: -0.1287962	total: 2m 9s	remaining: 9.31s
# 933:	learn: -0.1287529	total: 2m 9s	remaining: 9.17s
# 934:	learn: -0.1285576	total: 2m 9s	remaining: 9.03s
# 935:	learn: -0.1285077	total: 2m 10s	remaining: 8.89s
# 936:	learn: -0.1283599	total: 2m 10s	remaining: 8.76s
# 937:	learn: -0.1282628	total: 2m 10s	remaining: 8.62s
# 938:	learn: -0.1282353	total: 2m 10s	remaining: 8.48s
# 939:	learn: -0.1282124	total: 2m 10s	remaining: 8.34s
# 940:	learn: -0.1281377	total: 2m 10s	remaining: 8.2s
# 941:	learn: -0.1280338	total: 2m 10s	remaining: 8.06s
# 942:	learn: -0.1279995	total: 2m 11s	remaining: 7.92s
# 943:	learn: -0.1279676	total: 2m 11s	remaining: 7.78s
# 944:	learn: -0.1276577	total: 2m 11s	remaining: 7.64s
# 945:	learn: -0.1276260	total: 2m 11s	remaining: 7.5s
# 946:	learn: -0.1274881	total: 2m 11s	remaining: 7.37s
# 947:	learn: -0.1273484	total: 2m 11s	remaining: 7.23s
# 948:	learn: -0.1272729	total: 2m 11s	remaining: 7.09s
# 949:	learn: -0.1272355	total: 2m 12s	remaining: 6.95s
# 950:	learn: -0.1271840	total: 2m 12s	remaining: 6.81s
# 951:	learn: -0.1270167	total: 2m 12s	remaining: 6.67s
# 952:	learn: -0.1269581	total: 2m 12s	remaining: 6.53s
# 953:	learn: -0.1269250	total: 2m 12s	remaining: 6.39s
# 954:	learn: -0.1269059	total: 2m 12s	remaining: 6.25s
# 955:	learn: -0.1268759	total: 2m 12s	remaining: 6.12s
# 956:	learn: -0.1267624	total: 2m 13s	remaining: 5.98s
# 957:	learn: -0.1267301	total: 2m 13s	remaining: 5.84s
# 958:	learn: -0.1266777	total: 2m 13s	remaining: 5.7s
# 959:	learn: -0.1266610	total: 2m 13s	remaining: 5.56s
# 960:	learn: -0.1266477	total: 2m 13s	remaining: 5.42s
# 961:	learn: -0.1266192	total: 2m 13s	remaining: 5.28s
# 962:	learn: -0.1265771	total: 2m 13s	remaining: 5.14s
# 963:	learn: -0.1265430	total: 2m 13s	remaining: 5s
# 964:	learn: -0.1265334	total: 2m 14s	remaining: 4.86s
# 965:	learn: -0.1264077	total: 2m 14s	remaining: 4.72s
# 966:	learn: -0.1263928	total: 2m 14s	remaining: 4.59s
# 967:	learn: -0.1261926	total: 2m 14s	remaining: 4.45s
# 968:	learn: -0.1261690	total: 2m 14s	remaining: 4.31s
# 969:	learn: -0.1261467	total: 2m 14s	remaining: 4.17s
# 970:	learn: -0.1261297	total: 2m 14s	remaining: 4.03s
# 971:	learn: -0.1260684	total: 2m 15s	remaining: 3.89s
# 972:	learn: -0.1258718	total: 2m 15s	remaining: 3.75s
# 973:	learn: -0.1258098	total: 2m 15s	remaining: 3.61s
# 974:	learn: -0.1257041	total: 2m 15s	remaining: 3.47s
# 975:	learn: -0.1256465	total: 2m 15s	remaining: 3.33s
# 976:	learn: -0.1256214	total: 2m 15s	remaining: 3.2s
# 977:	learn: -0.1254779	total: 2m 15s	remaining: 3.06s
# 978:	learn: -0.1254548	total: 2m 16s	remaining: 2.92s
# 979:	learn: -0.1254132	total: 2m 16s	remaining: 2.78s
# 980:	learn: -0.1253829	total: 2m 16s	remaining: 2.64s
# 981:	learn: -0.1253466	total: 2m 16s	remaining: 2.5s
# 982:	learn: -0.1252438	total: 2m 16s	remaining: 2.36s
# 983:	learn: -0.1251665	total: 2m 16s	remaining: 2.22s
# 984:	learn: -0.1251019	total: 2m 16s	remaining: 2.08s
# 985:	learn: -0.1250196	total: 2m 17s	remaining: 1.95s
# 986:	learn: -0.1249810	total: 2m 17s	remaining: 1.81s
# 987:	learn: -0.1249241	total: 2m 17s	remaining: 1.67s
# 988:	learn: -0.1249141	total: 2m 17s	remaining: 1.53s
# 989:	learn: -0.1248651	total: 2m 17s	remaining: 1.39s
# 990:	learn: -0.1248416	total: 2m 17s	remaining: 1.25s
# 991:	learn: -0.1247580	total: 2m 17s	remaining: 1.11s
# 992:	learn: -0.1247163	total: 2m 18s	remaining: 973ms
# 993:	learn: -0.1246997	total: 2m 18s	remaining: 834ms
# 994:	learn: -0.1244891	total: 2m 18s	remaining: 695ms
# 995:	learn: -0.1244090	total: 2m 18s	remaining: 556ms
# 996:	learn: -0.1243668	total: 2m 18s	remaining: 417ms
# 997:	learn: -0.1242793	total: 2m 18s	remaining: 278ms
# 998:	learn: -0.1242418	total: 2m 18s	remaining: 139ms
# 999:	learn: -0.1242170	total: 2m 19s	remaining: 0us
# CPU times: user 4min 32s, sys: 51.9 s, total: 5min 24s
# Wall time: 5h 49min 36s

# %%
clf.best_params_
# Out:
# {'depth': 10, 'iterations': 1000, 'learning_rate': 1}

# %%
model = CatBoostClassifier(
    iterations=1000,
    depth=10,
    learning_rate=1,
    loss_function='MultiClass',
    custom_loss=['F1'],
    random_seed=SEED,
    logging_level='Silent'
)

# %%
model.fit(df_train[train_cols], y_train)

# %%
print('train', metrics.f1_score(y_train, model.predict(df_train[train_cols]), average='macro'))
print('test', metrics.f1_score(y_test, model.predict(df_test[train_cols]), average='macro'))
# Out:
# train 0.9996512534279905
# test 0.8274820993917573

# %% [markdown]
# `RandomForestClassifier`

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    random_state=SEED,
    max_depth=100,
    n_estimators=500,
    class_weight='balanced'
)

# %%
rf.fit(df_train[train_cols], y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=100, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=1, oob_score=False, random_state=1337,
#             verbose=0, warm_start=False)

# %%
print('train', metrics.f1_score(y_train, rf.predict(df_train[train_cols]), average='macro'))
print('test', metrics.f1_score(y_test, rf.predict(df_test[train_cols]), average='macro'))
# Out:
# train 0.9998132730662732
# test 0.8519797533974067
